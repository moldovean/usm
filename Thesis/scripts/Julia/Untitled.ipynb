# %%
using PyPlot

n = 50
srand(1)
x = rand(n)
y = rand(n)
area = pi .* (15 .* rand(n)).^2 # 0 to 15 point radiuses
scatter(x, y, s=area, alpha=0.5)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f5a3c0c7f10>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f5a33407550>

# %%
using QuantEcon

# %%
tauchen(4, 0.76, 1)
# Out:
# Discrete Markov Chain
# stochastic matrix of type Array{Float64,2}:
# 4x4 Array{Float64,2}:
#  0.6667       0.333074     0.000225653  2.2684e-11
#  0.0282009    0.850672     0.121117     1.08492e-5
#  1.08492e-5   0.121117     0.850672     0.0282009
#  2.26839e-11  0.000225653  0.333074     0.6667

# %%
A = [[0.8, 0.15,0.05]
    [0.5, 0.1, 0.4]
    [0.1,0.1,0.8]]
# Out:
# 9-element Array{Float64,1}:
#  0.8
#  0.15
#  0.05
#  0.5
#  0.1
#  0.4
#  0.1
#  0.1
#  0.8

# %%
A = reshape(A,3,3)
# Out:
# 3x3 Array{Float64,2}:
#  0.8   0.5  0.1
#  0.15  0.1  0.1
#  0.05  0.4  0.8

# %%
A = [0.8  0.15 0.05;
    0.5  0.1  0.4;
    0.1  0.1  0.8; ]
# Out:
# 3x3 Array{Float64,2}:
#  0.8  0.15  0.05
#  0.5  0.1   0.4
#  0.1  0.1   0.8

# %%
A = [0.971 0.1450 0.029; 0.7780.50800.0770.492]
# Out:
# 3x3 Array{Float64,2}:
#  0.500146  0.12501   0.374844
#  0.499994  0.125     0.375007
#  0.499807  0.124987  0.375206
